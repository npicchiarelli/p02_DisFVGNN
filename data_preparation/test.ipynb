# %%
import static_graph
from smithers.io.openfoam import FoamMesh
from mesh2graph.utils import parse_vertex_centered, add_boundary_points
# Out:
# /home/npicchia/miniconda3/envs/gnn_env/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import os
os.getcwd()
# Out:
# '/home/npicchia/fvgn/p02_DisFVGNN/data_preparation'

# %%
case_folder = "../tests/data/flange"
excluded_faces=["patch1", "patch3"]

stat_g = static_graph.build_static_graph(case_folder, excluded_faces)
# Out:
# I/O    : uncollated
# --> FOAM Warning :
#     From Foam::fileName Foam::cwd_L()
#     in file POSIX.C at line 552
#     PWD is not the cwd() - reverting to physical description
# Case   : /home/npicchia/fvgn/p02_DisFVGNN/tests/data/flange
# nProcs : 1
# Reading field p
#
# Create time
#
# Reading field p
#
# Create mesh for time = 3
#
# <class 'torch.Tensor'> torch.Size([31364, 3])
# <class 'torch.Tensor'> torch.Size([31364, 1])
# I/O    : uncollated
# --> FOAM Warning :
#     From Foam::fileName Foam::cwd_L()
#     in file POSIX.C at line 552
#     PWD is not the cwd() - reverting to physical description
# Case   : /home/npicchia/fvgn/p02_DisFVGNN/tests/data/flange
# nProcs : 1
# Reading field p
#
# Create time
#
# Reading field p
#
# Create mesh for time = 3
#
# I/O    : uncollated
# --> FOAM Warning :
#     From Foam::fileName Foam::cwd_L()
#     in file POSIX.C at line 552
#     PWD is not the cwd() - reverting to physical description
# ...

# %%
stat_g
# Out:
# Data(x=[6444, 5], edge_index=[2, 31364], edge_attr=[31364, 10])
